# %% [markdown]
# <a href="https://colab.research.google.com/github/mdjamina/L8DN001_document_structure/blob/main/scripts/wordcloudimage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import wordcloud as wc
from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image
import matplotlib.pyplot as plt
import nltk
nltk.download('punkt')
nltk.download('stopwords')
import pprint as pp

from nltk import word_tokenize
from nltk.corpus import stopwords
import string
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
french_stopwords = set(stopwords.words('french'))

# %%
def tokenizer(text,language = "french"):
    """onvertir text en une liste de mots/tokens     
    """
    lst = word_tokenize(text, language = language)
    return [w.lower() for w in lst if w not in string.punctuation]

# %%
def pic_generator(text,pic_file_name='wordcloudimage.png', max_words=250,max_font_size=250,stopwords=None,background_color='white',width=1000,height=720):

  wordcloudimage = WordCloud( max_words=max_words,font_step=2 , max_font_size=max_font_size, stopwords=stopwords, background_color=background_color, width=width, height=height, margin=0 ).generate(text)

  plt.figure(figsize=(20,8))
  plt.imshow(wordcloudimage)
  plt.axis("off")
  plt.show()
  wordcloudimage.to_file(pic_file_name)

# %%
text = """
       Structurer l’information
        Exercice 1 : Structurer l’information (vers une grammaire de document)

       
            XML permet de structurer une information. Il est donc nécessaire, avant d'envisager d'utiliser ce format, de se familariser avec cette structuration. Le paragraphe suivant contient de l'information "en vrac".
            Réorganisez-la de manière à mettre en évidence sa structure logique, sans forcément passer par une mise en forme XML.
       

        
                     Une bouteille d'eau Cristaline de 150 cl contient par litre 71 mg d'ions positifs calcium, et 5,5 mg d'ions positifs magnésium. On y trouve également des ions négatifs comme des chlorures à 20 mg par litre et des nitrates avec 1 mg par litre. Elle est recueillie à St-Cyr la Source, dans le département du Loiret. Son code barre est 3274080005003 et son pH est de 7,45. Comme la bouteille est sale, quelques autres matériaux comme du fer s'y trouvent en suspension.
               
                    Une seconde bouteille d'eau Cristaline a été, elle, recueillie à la source d'Aurèle dans les Alpes Maritimes. La concentration en ions calcium est de 98 mg/l, et en ions magnésium de 4 mg/l. Il y a 3,6 mg/l d'ions chlorure et 2 mg/l de nitrates, pour un pH de 7,4. Le code barre de cette bouteille de 50 cl est 3268840001008.
               
                
               
                    Une bouteille de même contenance est de marque Volvic, et a été puisée à... Volvic, bien connu pour ses sources donnant un pH neutre de 7. Elle comprend 11,5 mg/l d'ions calcium, 8,0 mg/l d'ions magnésium, 13,5 mg/l d'ions chlorures et 6,3 mg/l d'ions nitrates. Elle contient également des particules de silice. Son code barre est 3057640117008.
                     PS : Volvic est dans le Puy-de-Dôme...
  
"""

pic_generator(text,'exo1.png',width=1000, height=664)

# %%
text = """
Exercice3 : TEI
       créer un fichier XML TEI à partir d’un document txt obtenu par océrisation océrisation du Dictionnaire universel (1690) d’Antoine Furetière
        
        TEI TEI

        Dictionnaire universel        
  
"""

text = text + "Antiperistase " *2 +"   Apostre" *2 + "Exercice3 " *5

pic_generator(text,'exo33.png',width=1000, height=664)

# %%
text = """
       
  
"""

pic_generator(text,'exo4.png',width=1000, height=664)

# %%
text = """
 DUCHN (xml)
Exercice 5 : DUCHN (xml)
.Fichier de travail : duchn.xml (avec annotations morphosyntaxiques)
    Le texte duch.xml contient le texte du Père Duchesne :
    
        Le Père Duchesne
        est le titre de différents journaux qui ont paru sous plusieurs plumes durant la Révolution française. Le plus populaire était celui de Jacques-René Hébert, qui en a fait paraître 385 numéros de septembre 1790 jusqu’à onze jours avant sa mort à la guillotine, survenue le 4 germinal An II (24 mars 1794).
    

        
        un document HTML et donnant à voir uniquement le texte. On essaiera de formater au mieux l’affichage  (séparer les mots… saut de ligne après paragraphe…)

            un document HTML et donnant à voir uniquement le texte en surlignant les mots dont le lemme est « aristocrate » ou « patriote »
        
            (stylage à définir par vous pour marquer le soulignement visé).
        

        
         un document TXT contenant la liste des mots contenant la séquence « citoy », puis la séquence « patriot » ; compter aussi la fréquence de chacun des mots
        
        D document TXT contenant la liste des catégories ; compter aussi la fréquence de chacune

    
        
        
            Définir une feuille de style permettant d’afficher le texte en surlignant les mots de catégories NOM ou ADJ
            (stylage à définir par vous pour marquer le soulignement visé).
        


        
         un document TXT contenant la liste des séquences NOM ADJ


        
        Idem avec NOM PREP NOM

      
  
"""

text = (" Exercice5 " * 5 ) + text + (" annotations morphosyntaxiques " * 3) + (" DUCHN (xml) " *2)

pic_generator(text,'exo5.png',stopwords=french_stopwords ,width=1000, height=664, max_words=1250,max_font_size=1250)

# %%
" Exercice5" * 15
# Out:
# ' Exercice5 Exercice5 Exercice5 Exercice5 Exercice5 Exercice5 Exercice5 Exercice5 Exercice5 Exercice5 Exercice5 Exercice5 Exercice5 Exercice5 Exercice5'

# %%
text = """
       EXERCICE14 EXERCICE14    - Extraction dans les Fils RSS du Monde
               
            Partie 1 : Fichiers de travail : rubrique «A la Une» 2017 étiquetée avec treetagger
            Ce fichier est disponible dans une archive sous iCampus : 3208-2017-v2.zip
            Partie 2 : fichiers étiquetés avec udpipe dans le cours Projet Encadré
        EXERCICE14

     
                XSLT
                Construire une feuille de styles pour afficher les contenus étiquetés avec TreeTagger

            
                 XSLT
                Construire des feuilles de style pour extraire (au format TXT) au moins 3 patrons morpho-
                    syntaxiques (de longueurs différentes) sur les mêmes fichiers 

            
                XSLT
                Construire une feuille de styles pour afficher les contenus étiquetés avec TreeTagger en 
                    mettant au jour un patron morphosyntaxique. 
EXERCICE14
            
                 XQuery
                Construire une requête pour extraire les contenus textuels des titres 

            
                 XQuery
                Construire une requête pour extraire les contenus textuels des descriptions 

            
                 XQuery
                Construire une requête pour extraire les contenus textuels des titres ET des descriptions
EXERCICE14
            
                XQuery
                Construire une requête pour extraire les patrons morpho-syntaxiques NOM ADJ

            
                XQuery
                Construire une requête pour extraire les patrons morpho-syntaxiques NOM PRP NOM

  
"""



pic_generator(text,'exo142.png',stopwords=french_stopwords,width=1000, height=664)

# %%
text = """
       Patrons morphosyntaxiques  Relations de dépendance sur la Base TrameurFromRhapsodie
EXERCICE15 - Patrons morphosyntaxiques  Relations de dépendance sur la Base TrameurFromRhapsodie

         XSLT
        Construire une feuille de styles pour afficher uniquement le texte (sortie TXT)

    
       
        Construire une feuille de styles pour afficher (au format HTML) le texte en insérant sur chaque item sa POS
            Cet exercice a été effectué sur l'échantillon fournit sur iCampus de la base TrameurFromRhapsodie.

    
        
        Construire une feuille de styles pour extraire (en format TXT) au moins 2 patrons morpho-syntaxiques de longueurs différentes
            les patrons  choisis: NOM-NOM et NOM-VERBE-ADJECTIF

 EXERCICE15   
        
        Construire une feuille de styles pour extraire (au format TXT) les items en relation de dépendance syntaxique de type SUJET (les classer et les compter)
            
            Cet exercice a également été effectué sur l'échantillon fournit sur iCampus de la base TrameurFromRhapsodie. Le classement et le comptage ont été fait en ligne de commande : xsltproc Q4.xsl ..baseTrameurFromRhapsodie-echantillon.xml | sort | uniq -c | sort -nr > Q4.txt

    
         
        Construire une feuille de styles pour extraire la liste des POS en relation de dépendance syntaxique de type SUJET (les classer et les compter)
            
            Ici aussi, le classement et le comptage ont été fait en ligne de commande : xsltproc Q5.xsl ..baseTrameurFromRhapsodie-echantillon.xml | sort | uniq -c | sort -nr > Q5.txt
EXERCICE15
    
          Question subsidiaire
        Construire une feuille de styles pour afficher (au format HTML) tout le texte de la base en mettant au jour une relation de dépendance syntaxique choisie (par exemple OBJ) : l’affichage doit mettre au jour le dépendant et le gouverneur
            
            La relation de dépendance syntaxique que j'ai choisi est la relation SUB (sujet).
EXERCICE15 EXERCICE15
    
         XQuery
        Construire une requête pour extraire les items portant une relation de dépendance syntaxique de type OBJ

   EXERCICE15 
         
        Construire une requête pour extraire les items en relation de dépendance syntaxique de type OBJ (on affichera les formes ou les lemmes connectés par cette relation)

  
"""

pic_generator(text,'exo154.png',stopwords=french_stopwords,width=1000, height=664)

# %%
pic_generator(text,'exo1.png',width=1000, height=664)

# %% [markdown]
# ../images/hors-sentiers2.jpg (L1170*H400)
# france_fchif_traineaux218_c_migeon-r.jpg (1000x664
